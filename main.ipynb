# %% [markdown]
# # Preços dos carros da polônia
# <p>Site: https://www.kaggle.com/ </p>
# <p>Dowload dos dados: https://www.kaggle.com/aleksandrglotov/car-prices-poland/download </p>
# <p>Site dos dados: https://www.kaggle.com/aleksandrglotov/car-prices-poland </p>

# %%
import pandas as pd
import numpy as np

# %%
#Lendo o arquivo csv
df = pd.read_csv("data/Car_Prices_Poland_Kaggle.csv", encoding='utf8', sep=",", index_col=0)
df.head()
df.price = np.int32(df.price)

# %%
#Carro com o preço mais alto
df[df.price == df.price.max()]
# Out:
#                 mark    model generation_name  year  mileage  vol_engine  \
# 61836  mercedes-benz  s-klasa   gen-w222-2013  2017      400        5980
#
#            fuel   city     province    price
# 61836  Gasoline  Janki  Mazowieckie  2399900

# %%
#Carro com o preço mais baixo
df[df.price == df.price.min()]
# Out:
#              mark      model generation_name  year  mileage  vol_engine  \
# 38890  volkswagen  golf-plus             NaN  2007   300567        1598
#
#            fuel       city        province  price
# 38890  Gasoline  Lubachowy  Świętokrzyskie    500

# %%
#Média dos preços
df.price.mean()
# Out:
# 70299.88479313474

# %%
#maiores preços de dos gol-plus
df[df.price == df[df.model == "golf-plus"].price.max()]
# Out:
#          mark   model   generation_name  year  mileage  vol_engine      fuel  \
# 190      opel    adam               NaN  2014    98317        1398       LPG
# 217      opel    adam               NaN  2016    54000         999  Gasoline
# 222      opel    adam               NaN  2014    98317        1398       LPG
# 249      opel    adam               NaN  2016    54000         999  Gasoline
# 381      opel  antara               NaN  2014   237000        2231    Diesel
# ...       ...     ...               ...   ...      ...         ...       ...
# 115418  volvo     v60   gen-i-2011-2018  2012   223690        1560    Diesel
# 115421  volvo     v60   gen-i-2011-2018  2011   241000        1984    Diesel
# 115453  volvo     v60   gen-i-2011-2018  2012   214000        1560    Diesel
# 115485  volvo     v60   gen-i-2011-2018  2011   216000        1984    Diesel
# 115640  volvo     v70  gen-iii-2007-v70  2008   270000        2521  Gasoline
#
#              city       province  price
# ...
